# %% [markdown]
# # Reparameterize force fields
#
# The `MMForceFieldGenerator` class in `VeloxChem` provides a number of functions to manipulate topology files. As an example, we consider the optimization of the force field parameters for a dihedral angle of a thiophene-based optical ligand named HS-276.
#
# Load the required modules and the equilibrium geometry:

# %%
import veloxchem as vlx
import numpy as np

# load B3LYP optimized geometry in the xyz format
molecule = vlx.Molecule.read_xyz_file("../../data/md/hs276.xyz")
molecule.show(atom_indices=True, width=600, height=450)
# Out:
# <div id="3dmolviewer_1743499991241348"  style="position: relative; width: 600px; height: 450px;">
#         <p id="3dmolwarning_1743499991241348" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_1743499991241348 = null;
# var warn = document.getElementById("3dmolwarning_1743499991241348");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1743499991241348 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1743499991241348"),{backgroundColor:"white"});
# viewer_1743499991241348.zoomTo();
# 	viewer_1743499991241348.addModel("35\n\nC              4.373000000000         0.283000000000        -0.025000000000\nC              4.415000000000         1.595000000000        -0.512000000000\nH              3.512000000000         2.197000000000        -0.625000000000\nN              5.570000000000         2.158000000000        -0.868000000000\nC              6.709000000000         1.437000000000        -0.751000000000\nH              7.623000000000         1.952000000000        -1.052000000000\nC              6.768000000000         0.125000000000        -0.292000000000\nH              7.720000000000        -0.402000000000        -0.234000000000\nC              5.560000000000        -0.488000000000         0.083000000000\nC              5.181000000000        -1.787000000000         0.570000000000\nH              5.834000000000        -2.627000000000         0.778000000000\nC              3.821000000000        -1.767000000000         0.740000000000\nH              3.152000000000        -2.538000000000         1.110000000000\nN              3.307000000000        -0.521000000000         0.391000000000\nC              1.957000000000        -0.159000000000         0.437000000000\nS              0.730000000000        -1.238000000000        -0.213000000000\nC              1.403000000000         1.005000000000         0.911000000000\nH              1.989000000000         1.800000000000         1.365000000000\nC             -0.012000000000         1.036000000000         0.774000000000\nH             -0.623000000000         1.870000000000         1.113000000000\nC             -0.550000000000        -0.103000000000         0.208000000000\nC             -1.939000000000        -0.434000000000        -0.042000000000\nC             -2.470000000000        -1.612000000000        -0.545000000000\nH             -1.859000000000        -2.469000000000        -0.822000000000\nC             -3.881000000000        -1.591000000000        -0.658000000000\nH             -4.487000000000        -2.414000000000        -1.028000000000\nS             -3.211000000000         0.726000000000         0.293000000000\nC             -4.440000000000        -0.400000000000        -0.246000000000\nC             -5.874000000000        -0.081000000000        -0.247000000000\nO             -6.746000000000        -0.844000000000        -0.616000000000\nO             -6.116000000000         1.171000000000         0.215000000000\nC             -7.501000000000         1.564000000000         0.245000000000\nH             -8.073000000000         0.894000000000         0.899000000000\nH             -7.504000000000         2.584000000000         0.637000000000\nH             -7.928000000000         1.534000000000        -0.765000000000\n");
# 	viewer_1743499991241348.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1743499991241348.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1743499991241348.addLabel("1",{"position": {"x": 4.373, "y": 0.283, "z": -0.024999999999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("2",{"position": {"x": 4.415, "y": 1.595, "z": -0.512}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("3",{"position": {"x": 3.512, "y": 2.197, "z": -0.625}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("4",{"position": {"x": 5.57, "y": 2.158, "z": -0.868}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("5",{"position": {"x": 6.709, "y": 1.437, "z": -0.7509999999999999}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("6",{"position": {"x": 7.622999999999999, "y": 1.952, "z": -1.052}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("7",{"position": {"x": 6.768, "y": 0.125, "z": -0.292}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("8",{"position": {"x": 7.72, "y": -0.402, "z": -0.23399999999999999}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("9",{"position": {"x": 5.56, "y": -0.488, "z": 0.083}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("10",{"position": {"x": 5.180999999999999, "y": -1.787, "z": 0.57}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("11",{"position": {"x": 5.834, "y": -2.627, "z": 0.778}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("12",{"position": {"x": 3.821, "y": -1.767, "z": 0.7399999999999999}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("13",{"position": {"x": 3.1519999999999997, "y": -2.538, "z": 1.1099999999999999}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("14",{"position": {"x": 3.307, "y": -0.521, "z": 0.391}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("15",{"position": {"x": 1.957, "y": -0.159, "z": 0.43699999999999994}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("16",{"position": {"x": 0.73, "y": -1.238, "z": -0.213}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("17",{"position": {"x": 1.4029999999999998, "y": 1.005, "z": 0.9109999999999999}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("18",{"position": {"x": 1.9889999999999999, "y": 1.8, "z": 1.365}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_1743499991241348.addLabel("19",{"position": {"x": -0.012, "y": 1.036,

# %% [markdown]
# We here consider the dihedral angle between the two thiophene rings, which corresponds to the rotation around bond 21-22.
#
# The dihedral potential curves will be plotted using force field parameters from the general amber forcefield (GAFF) database, as compared to QM results. The force field will then be changed to better fit this potential.

# %% [markdown]
# ## Create the initial force field
#
# Initialize an `MMForceFieldGenerator` object and generate initial force field with pre-calculated [RESP charges](../env/resp):

# %%
resp_chg = np.array([
    0.014967, 0.224409, 0.089489, -0.551618, 0.153050, 0.106847, -0.315042,
    0.165854, 0.206441, -0.425163, 0.225816, -0.039099, 0.179377, 0.002119,
    0.014483, -0.043666, -0.230202, 0.165960, -0.071404, 0.188598, -0.044661,
    0.088786, -0.173586, 0.175730, -0.089376, 0.164515, -0.118573, -0.150541,
    0.736497, -0.570770, -0.273724, -0.144051, 0.112846, 0.112846, 0.112846
])

ff_gen = vlx.MMForceFieldGenerator()
ff_gen.partial_charges = resp_chg
ff_gen.create_topology(molecule)
# Out:
# * Info * Using GAFF (v2.11) parameters.
#          Reference: J. Wang, R. M. Wolf, J. W. Caldwell, P. A. Kollman, D. A. Case, J. Comput. Chem. 2004,
#          25, 1157-1174.
#
# * Info * Updated bond angle 1-9-10 (ca-ca-cc) to 107.217 deg
# * Info * Updated bond angle 1-14-15 (ca-na-cc) to 126.641 deg
# * Info * Updated bond angle 2-1-14 (ca-ca-na) to 131.687 deg
# * Info * Updated bond angle 7-9-10 (ca-ca-cc) to 135.297 deg
# * Info * Updated bond angle 9-1-14 (ca-ca-na) to 107.608 deg
# * Info * Updated bond angle 14-15-17 (na-cc-cd) to 128.324 deg
# * Info * Updated bond angle 19-21-22 (cd-cc-cc) to 129.220 deg
# * Info * Updated bond angle 21-22-23 (cc-cc-cd) to 128.571 deg

# %% [markdown]
# ## Reparameterize the force field
#
# Use the `reparameterize_dihedrals` method to fit dihedral parameters to QM scan. If you would like to see more output during the fitting, set `verbose` to `True`.

# %%
reparam_summary = ff_gen.reparameterize_dihedrals(rotatable_bond=(21,22),
                                                  scan_file="../../data/md/27-22-21-16.xyz",
                                                  visualize=True,
                                                  verbose=False)
# Out:
#                                           VeloxChem Dihedral Reparameterization
#                                           =====================================
#
# * Info * Rotatable bond selected: 21-22
# * Info * Dihedrals involved:[[16, 21, 22, 23], [16, 21, 22, 27], [19, 21, 22, 23], [19, 21, 22, 27]]
# * Info * Reading QM scan from file...
# * Info *   ../../data/md/27-22-21-16.xyz
#
# * Info * Performing dihedral scan for MM baseline by excluding the involved dihedral barriers...
#
# * Info *   Target dihedral angle: 16-21-22-27
#
# * Info * Dihedral barriers [4.184 4.184 4.184 4.184] will be used as initial guess.
# * Info * Validating the initial force field...
#
# * Info * Summary of validation
# * Info * ---------------------
# * Info * Maximum difference: 19.212 kJ/mol
# * Info * Standard deviation: 6.677 kJ/mol
# * Info * Fitting the dihedral parameters...
# * Info * Optimizing dihedral via least squares fitting...
# * Info * New fitted barriers: [1.85974413 1.85974413 1.85974413 1.85974413]
# * Info * Validating the fitted force field...
#
# * Info * Summary of validation
# * Info * ---------------------
# * Info * Maximum difference: 5.311 kJ/mol
# * Info * Standard deviation: 1.753 kJ/mol
# * Info * Dihedral MM parameters have been reparameterized and updated in the topology.

# %% [markdown]
# It is not uncommon that the existing dihedral terms in the force field are not sufficient to reproduce the QM potential. Here we can try adding more dihedral terms to the force field, and then redo the fitting. In this particular case we would like to lower the MM energy at 0$^{\circ}$ so that it matches the QM energy better. This corresponds to adding a dihedral term with periodicity 1 and phase 180$^{\circ}$. The barrier can be set to 0 since it will be fitted.

# %%
ff_gen.add_dihedral((16, 21, 22, 27), barrier=0.0, phase=180.0, periodicity=1)
# Out:
# * Info * Added dihedral 16-21-22-27

# %% [markdown]
# After adding the dihedral term we can redo the fitting. This time we can skip the initial validation step by setting `initial_validation` to `False`, since we already know how the MM potential energy curve looks. We can also set `show_diff` to `True` so that the difference between QM and MM energies will be plotted after the fitting.

# %%
reparam_summary = ff_gen.reparameterize_dihedrals(rotatable_bond=(21,22),
                                                  scan_file="../../data/md/27-22-21-16.xyz",
                                                  visualize=True,
                                                  verbose=False,
                                                  initial_validation=False,
                                                  show_diff=True)
# Out:
#                                           VeloxChem Dihedral Reparameterization
#                                           =====================================
#
# * Info * Rotatable bond selected: 21-22
# * Info * Dihedrals involved:[[16, 21, 22, 23], [16, 21, 22, 27], [19, 21, 22, 23], [19, 21, 22, 27]]
# * Info * Reading QM scan from file...
# * Info *   ../../data/md/27-22-21-16.xyz
#
# * Info * Performing dihedral scan for MM baseline by excluding the involved dihedral barriers...
#
# * Info *   Target dihedral angle: 16-21-22-27
#
# * Info * Dihedral barriers [1.85974413 1.85974413 0.         1.85974413 1.85974413] will be used as initial guess.
# * Info * Fitting the dihedral parameters...
# * Info * Optimizing dihedral via least squares fitting...
# * Info * New fitted barriers: [1.98197174 1.98197174 1.97103413 1.98197174 1.98197174]
# * Info * Validating the fitted force field...
#
# * Info * Summary of validation
# * Info * ---------------------
# * Info * Maximum difference: 2.368 kJ/mol
# * Info * Standard deviation: 0.969 kJ/mol
# * Info * Dihedral MM parameters have been reparameterized and updated in the topology.

# %% [markdown]
# Now we get better agreement between QM and MM energies. Since the difference between QM and MM is also plotted, we can tell that the MM energies can be brought closer to QM energies by adding one more dihedral term with periodicity 4 and phase 0$^{\circ}$.

# %%
ff_gen.add_dihedral((16, 21, 22, 27), barrier=0.0, phase=0.0, periodicity=4)
# Out:
# * Info * Added dihedral 16-21-22-27

# %%
reparam_summary = ff_gen.reparameterize_dihedrals(rotatable_bond=(21,22),
                                                  scan_file="../../data/md/27-22-21-16.xyz",
                                                  visualize=True,
                                                  verbose=False,
                                                  initial_validation=False)
# Out:
#                                           VeloxChem Dihedral Reparameterization
#                                           =====================================
#
# * Info * Rotatable bond selected: 21-22
# * Info * Dihedrals involved:[[16, 21, 22, 23], [16, 21, 22, 27], [19, 21, 22, 23], [19, 21, 22, 27]]
# * Info * Reading QM scan from file...
# * Info *   ../../data/md/27-22-21-16.xyz
#
# * Info * Performing dihedral scan for MM baseline by excluding the involved dihedral barriers...
#
# * Info *   Target dihedral angle: 16-21-22-27
#
# * Info * Dihedral barriers [1.98197174 1.98197174 1.97103413 0.         1.98197174 1.98197174] will be used as initial guess.
# * Info * Fitting the dihedral parameters...
# * Info * Optimizing dihedral via least squares fitting...
# * Info * New fitted barriers: [2.00263461 2.00263461 1.90578785 1.23978392 2.00263461 2.00263461]
# * Info * Validating the fitted force field...
#
# * Info * Summary of validation
# * Info * ---------------------
# * Info * Maximum difference: 0.344 kJ/mol
# * Info * Standard deviation: 0.197 kJ/mol
# * Info * Dihedral MM parameters have been reparameterized and updated in the topology.

# %% [markdown]
# ## Save the force field to file
#
# Use `write_gromacs_files` or `write_openmm_files` to write the force field to files.

# %%
ff_gen.write_gromacs_files('hs276')
