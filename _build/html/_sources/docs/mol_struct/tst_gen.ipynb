# %% [markdown]
# # Transition state
#
# Once we have a suitable candidate for transition state we can optimize the structure for a transition state. As explained before the transition state will be characterized by a vanishing gradient and one negative Hessian
# eigenvalue. Therefore, in essence, we are exploring the PES looking for a maximum.<br />
# <br />
# To ilustrate the concepts we will use a simple example in which we will perform the Intrinsic Reaction Coordinate (IRC) method. So, we will start with a transition state candidate and optimize it to transition state. Then we will just minimize the energy in the backward path and the forward path to obtain the reactant and the product as illustrated in the following figure:<br />
# ```{figure} ../../img/pes/irc.png
# ```

# %% [markdown]
# ### Intrinsic Reaction Coordinate method
#
# The Intrinsic Reaction Coordinate method traces the minimum energy pathway of a chemical reaction, connecting an optimized transition state characterized by a single imaginary frequency to the neighbouring reactant and product minima. <br />
# <br />
# The calculation starts from the optimized TS structure, after the Hessian and vibrational frequencies have been determined. The eigenvector, corresponding to the imaginary vibrational mode defines the displacement vector, which sets the direction along which the system initially moves away from the TS.<br />
# <br />
# The first step is taken in the positive "forward" direction along this eingenvector using mass-weighted internal coordinates. At each step, the Hessian is updated, and the subsequent steps are guided by the instantaneous acceleration vectors. The procedure continues iteratively until convergence is reached in the "forward" direction, then is repeated in the negative "backward" direction to complete the full energy profile.

# %%
import veloxchem as vlx
import py3Dmol as p3d

# %%
ts_guess = '''8
Initial geometry
C        1.4059000000    0.8128000000    0.0009000000
C        1.5654000000   -0.3926000000    0.0009000000
N       -1.0383000000    1.0196000000   -0.0052000000
H       -2.0386000000    1.4291000000    0.0210000000
H        1.3741000000    1.8940000000   -0.0007000000
H        1.9546000000   -1.4028000000    0.0003000000
N       -0.4958000000   -1.3375000000   -0.0011000000
N       -1.1970000000   -0.3166000000    0.0018000000
'''

# %%
molecule = vlx.Molecule.from_xyz_string(ts_guess)
molecule.show()
# Out:
# <div id="3dmolviewer_17575427397772462"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17575427397772462" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17575427397772462 = null;
# var warn = document.getElementById("3dmolwarning_17575427397772462");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17575427397772462 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17575427397772462"),{backgroundColor:"white"});
# viewer_17575427397772462.zoomTo();
# 	viewer_17575427397772462.addModel("8\n\nC              1.405900000000         0.812800000000         0.000900000000\nC              1.565400000000        -0.392600000000         0.000900000000\nN             -1.038300000000         1.019600000000        -0.005200000000\nH             -2.038600000000         1.429100000000         0.021000000000\nH              1.374100000000         1.894000000000        -0.000700000000\nH              1.954600000000        -1.402800000000         0.000300000000\nN             -0.495800000000        -1.337500000000        -0.001100000000\nN             -1.197000000000        -0.316600000000         0.001800000000\n");
# 	viewer_17575427397772462.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17575427397772462.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17575427397772462.zoomTo();
# viewer_17575427397772462.render();
# });
# </script>

# %% [markdown]
# **Fig 1**: TS candidate

# %% [markdown]
# ##### Setting up the SCF driver

# %%
basis = vlx.MolecularBasis.read(molecule,"def2-svp")
scf_drv = vlx.ScfRestrictedDriver()
scf_drv.conv_thresh = 1.0e-6
scf_drv.xcfun = "b3lyp"
scf_drv.grid_level = 4
scf_drv.ostream.mute()
scf_results = scf_drv.compute(molecule,basis)

# %% [markdown]
# ##### Setting up the gradient driver

# %%
scf_grad_drv = vlx.ScfGradientDriver(scf_drv)
scf_grad_drv.compute (molecule,basis)

# %% [markdown]
# ##### Setting up the optimization driver

# %%
scf_opt_drv = vlx.OptimizationDriver(scf_drv)
scf_opt_drv.transition = True # We set the option to find transition state
scf_opt_drv.hessian = 'first+last'
scf_opt_drv.ostream.mute()
scf_opt_ts = scf_opt_drv.compute(molecule, basis, scf_results)

# %% [markdown]
# ##### Geometry of the optimized transition state

# %%
scf_opt_drv.show_convergence(scf_opt_ts)
# Out:
# <div id="3dmolviewer_1757516420799629"  style="position: relative; width: 640px; height: 360px;">
#         <p id="3dmolwarning_1757516420799629" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_1757516420799629 = null;
# var warn = document.getElementById("3dmolwarning_1757516420799629");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1757516420799629 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1757516420799629"),{backgroundColor:"white"});
# viewer_1757516420799629.zoomTo();
# 	viewer_1757516420799629.addModel("8\n\nC              1.267384028538         0.858861037274         0.111578248080\nC              1.514871770868        -0.354653532687         0.079330040429\nN             -0.878745542430         0.895731928573        -0.219123178544\nH             -1.690001642583         1.431578662084         0.102595977912\nH              1.377961209568         1.927169226772         0.160713109770\nH              2.093028695206        -1.262042519530         0.099900426819\nN             -0.381673301953        -1.312215794361        -0.182596621457\nN             -1.037548344687        -0.348440777236        -0.199319887647\n");
# 	viewer_1757516420799629.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1757516420799629.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1757516420799629.zoomTo();
# viewer_1757516420799629.render();
# });
# </script>
# interactive(children=(IntSlider(value=27, description='step', max=27), Output()), _dom_classes=('widget-intera…

# %% [markdown]
# ##### Vibrational Analysis
# To confirm that we obtained the TS, we will perform a vibrational analysis.

# %%
opt_molecule = vlx.Molecule.from_xyz_string(scf_opt_ts['final_geometry'])
opt_scf_drv = vlx.ScfRestrictedDriver()
opt_scf_drv.xcfun = "b3lyp"
opt_scf_results = opt_scf_drv.compute(opt_molecule, basis)

vib_drv = vlx.VibrationalAnalysis(opt_scf_drv)
vib_drv.update_settings(method_dict={'xcfun': 'b3lyp', 'grid_level':4})

vib_results = vib_drv.compute(opt_molecule, basis)
# Out:
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Kohn-Sham
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#                    Exchange-Correlation Functional : B3LYP
#                    Molecular Grid Level            : 4
#
# * Info * Nuclear repulsion energy: 148.8029764468 a.u.
#
# * Info * Using the B3LYP functional.
#
#          P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch.,  J. Phys. Chem. 98, 11623 (1994)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * Molecular grid with 121661 points generated in 0.13 sec.
#
# * Info * Overlap matrix computed in 0.02 sec.
#
# * Info * Kinetic energy matrix computed in 0.00 sec.
#
# * Info * Nuclear potential matrix computed in 0.00 sec.
#
# * Info * Orthogonalization matrix computed in 0.00 sec.
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -240.271814063223 a.u. Time: 0.31 sec.
#
# * Info * Overlap matrix computed in 0.00 sec.
#
# * Info * Kinetic energy matrix computed in 0.00 sec.
#
# * Info * Nuclear potential matrix computed in 0.00 sec.
#
# * Info * Orthogonalization matrix computed in 0.00 sec.
#
#
#                Iter. |    Kohn-Sham Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   
#                (   7 N   2p-1:    -0.16) (   8 N   3s  :    -0.44) (   8 N   1p+1:    -0.31)
#                (   8 N   2p+1:     0.28)
#
#                Molecular Orbital No.  20:
#                --------------------------
#                Occupation: 0.000 Energy:    0.00775 a.u.
#                (   1 C   2p0 :    -0.17) (   2 C   2p0 :     0.16) (   3 N   3s  :    -0.16)
#                (   3 N   1p0 :    -0.30) (   3 N   2p+1:     0.15) (   3 N   2p0 :     0.34)
#                (   4 H   2s  :     0.18) (   7 N   1p0 :    -0.39) (   7 N   2p0 :     0.45)
#                (   8 N   1p0 :     0.49) (   8 N   2p0 :    -0.52)
#
#                Molecular Orbital No.  21:
#                --------------------------
#                Occupation: 0.000 Energy:    0.03196 a.u.
#                (   1 C   1p0 :     0.39) (   1 C   2p0 :     0.65) (   2 C   1p0 :    -0.42)
#                (   2 C   2p0 :    -0.66) (   7 N   1p0 :    -0.17) (   7 N   2p0 :     0.17)
#
#                Molecular Orbital No.  22:
#                --------------------------
#                Occupation: 0.000 Energy:    0.04064 a.u.
#                (   1 C   2s  :    -0.17) (   1 C   1p+1:     0.27) (   1 C   2p+1:     0.40)
#                (   1 C   2p-1:    -0.50) (   2 C   2s  :     0.22) (   2 C   1p+1:    -0.29)
#                (   2 C   1p-1:    -0.15) (   2 C   2p+1:    -0.20) (   2 C   2p-1:    -0.64)
#                (   3 N   2s  :     0.18) (   3 N   3s  :     0.59) (   4 H   2s  :    -0.61)
#                (   5 H   2s  :     0.72) (   6 H   2s  :    -0.74) (   7 N   1p+1:     0.21)
#                (   7 N   2p+1:    -0.20) (   8 N   3s  :    -0.17)
#
#                Molecular Orbital No.  23:
#                --------------------------
#                Occupation: 0.000 Energy:    0.06708 a.u.
#                (   1 C   2s  :    -0.16) (   1 C   3s  :    -0.28) (   1 C   2p-1:    -0.60)
#                (   2 C   3s  :    -0.15) (   2 C   2p-1:    -0.34) (   3 N   3s  :    -0.98)
#                (   3 N   1p+1:    -0.24) (   3 N   2p+1:     0.44) (   3 N   2p0 :    -0.19)
#                (   4 H   2s  :     1.40) (   5 H   2s  :     0.94) (   6 H   2s  :    -0.37)
#                (   8 N   3s  :     0.21)
#
#
#                                                 Ground State Dipole Moment
#                                                ----------------------------
#
#                                    X   :        -0.242227 a.u.        -0.615680 Debye
#                                    Y   :         0.712090 a.u.         1.809953 Debye
#                                    Z   :         0.257673 a.u.         0.654939 Debye
#                                  Total :         0.795073 a.u.         2.020875 Debye
#
#
#                                                Vibrational Analysis Driver
#                                               =============================
#
#                           The following will be computed:
#
#                           - Vibrational frequencies and normal modes
#                           - Force constants
#                           - IR intensities
#
#
#                                                     SCF Hessian Driver
#                                                    ====================
#
#                           Hessian Type                    : Analytical
#                           Exchange-Correlation Functional : B3LYP
#                           Molecular Grid Level            : 4
#
# * Info * Computing analytical Hessian...
#
#          Reference: P. Deglmann, F. Furche, R. Ahlrichs, Chem. Phys. Lett. 2002, 362, 511-518.
#
#
#                                          Coupled-Perturbed Kohn-Sham Solver Setup
#                                         ==========================================
#
#                           Solver Type                     : Iterative Subspace Algorithm
#                           Max. Number of Iterations       : 150
#                           Convergence Threshold           : 1.0e-04
#                           Exchange-Correlation Functional : B3LYP
#                           Molecular Grid Level            : 4
#
# * Info * Using the B3LYP functional.
#
#          P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch.,  J. Phys. Chem. 98, 11623 (1994)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * Molecular grid with 121661 points generated in 0.08 sec.
#
# * Info * CPHF/CPKS integral derivatives computed in 3.20 sec.
#
# * Info * CPHF/CPKS right-hand side computed in 5.94 sec.
#
# * Info * Processing 21 Fock builds...
#
# * Info * 21 trial vectors in reduced space
#
# * Info * 638.22 kB of memory used for subspace procedure on the master node
# * Info * 70.57 GB of memory available for the solver on the master node
#
#                *** Iteration:   1 * Residuals (Max,Min): 5.30e-01 and 7.01e-02
#
# * Info * Processing 21 Fock builds...
#
# * Info * 42 trial vectors in reduced space
#
# * Info * 1.04 MB of memory used for subspace procedure on the master node
# * Info * 70.57 GB of memory available for the solver on the master node
#
#                *** Iteration:   2 * Residuals (Max,Min): 7.57e-02 and 6.10e-03
#
# * Info * Processing 21 Fock builds...
#
# * Info * 63 trial vectors in reduced space
#
# * Info * 1.45 MB of memory used for subspace procedure on the master node
# * Info * 70.59 GB of memory available for the solver on the master node
#
#                *** Iteration:   3 * Residuals (Max,Min): 7.29e-03 and 7.71e-04
#
# * Info * Processing 19 Fock builds...
#
# * Info * 82 trial vectors in reduced space
#
# * Info * 1.83 MB of memory used for subspace procedure on the master node
# * Info * 70.59 GB of memory available for the solver on the master node
#
#                *** Iteration:   4 * Residuals (Max,Min): 4.54e-04 and 7.22e-05
#
# * Info * Processing 18 Fock builds...
#
# * Info * 100 trial vectors in reduced space
#
# * Info * 2.39 MB of memory used for subspace procedure on the master node
# * Info * 70.60 GB of memory available for the solver on the master node
#
#                *** Iteration:   5 * Residuals (Max,Min): 1.00e-04 and 7.74e-06
#
#                *** Coupled-Perturbed Kohn-Sham converged in 5 iterations. Time: 20.42 sec
#
#
# * Info * First order derivative contributions to the Hessian computed in 0.00 sec.
#
# * Info * Second order derivative contributions to the Hessian computed in 9.38 sec.
#
#                                    *** Time spent in Hessian calculation: 29.85 sec ***
#
#
#                                                    Free Energy Analysis
#                                                   ======================
#
#        Note: Rotational symmetry is set to 1 regardless of true symmetry
#        1 Imaginary Frequencies (cm^-1): 499.708i
#        Note: Free energy does not include contribution from imaginary mode(s)
#
#        Free energy contributions calculated at @ 298.15 K:
#        Zero-point vibrational energy:                                   32.0253 kcal/mol
#        H   (Trans + Rot + Vib = Tot):   1.4812 +   0.8887 +   1.4860 =   3.8559 kcal/mol
#        S   (Trans + Rot + Vib = Tot):  38.6409 +  24.8989 +   7.7808 =  71.3207 cal/mol/K
#        TS  (Trans + Rot + Vib = Tot):  11.5208 +   7.4236 +   2.3199 =  21.2643 kcal/mol
#
#        Ground State Electronic Energy    : E0                        =  -241.90389602 au (   -151796.9866 kcal/mol)
#        Free Energy Correction (Harmonic) : ZPVE + [H-TS]_T,R,V       =     0.02329366 au (        14.6170 kcal/mol)
#        Gibbs Free Energy (Harmonic)      : E0 + ZPVE + [H-TS]_T,R,V  =  -241.88060237 au (   -151782.3696 kcal/mol)
#
#
#                                                    Vibrational Analysis
#                                                   ======================
#
# * Info * The 5 dominant normal modes are printed below.
#
#                                    Vibrational Mode      1
#                                    ----------------------------------------------------
#                                    Harmonic frequency:                -499.71  cm**-1
#                                    Reduced mass:                       6.3846  amu
#                                    Force constant:                     0.9393  mdyne/A
#                                    IR intensity:                     112.3739  km/mol
#                                    Normal mode:
#                                                               X           Y           Z
#                                    1       C             0.3521      0.0158      0.0397
#                                    2       C             0.3381      0.1053      0.0487
#                                    3       N            -0.3130      0.0190     -0.0342
#                                    4       H            -0.5225     -0.2539     -0.1162
#                                    5       H            -0.2429      0.0634     -0.0114
#                                    6       H            -0.2572     -0.2573     -0.0305
#                                    7       N            -0.2798     -0.1168     -0.0354
#                                    8       N             0.0746      0.0262      0.0053
#
#
#                                    Vibrational Mode      7
#                                    ----------------------------------------------------
#                                    Harmonic frequency:                 683.24  cm**-1
#                                    Reduced mass:                       2.8642  amu
#                                    Force constant:                     0.7878  mdyne/A
#                                    IR intensity:                     113.8464  km/mol
#                                    Normal mode:
#                                                               X           Y           Z
#                                    1       C            -0.1539     -0.0351     -0.0424
#                                    2       C            -0.0866      0.0042     -0.0011
#                                    3       N             0.0030      0.0572     -0.0087
#                                    4       H            -0.1812     -0.1102     -0.1978
#                                    5       H            -0.3496     -0.0306      0.1239
#                                    6       H            -0.7009     -0.3692     -0.0411
#                                    7       N            -0.0049     -0.0769     -0.0365
#                                    8       N             0.2968      0.0829      0.0908
#
#
#                                    Vibrational Mode      12
#                                    ----------------------------------------------------
#                                    Harmonic frequency:                1205.24  cm**-1
#                                    Reduced mass:                       1.2476  amu
#                                    Force constant:                     1.0678  mdyne/A
#                                    IR intensity:                     138.6046  km/mol
#                                    Normal mode:
#                                                               X           Y           Z
#                                    1       C            -0.0069      0.0007     -0.0043
#                                    2       C             0.0056      0.0013      0.0002
#                                    3       N             0.1006      0.0549     -0.0222
#                                    4       H            -0.5117     -0.8462      0.0531
#                                    5       H             0.0250     -0.0026      0.0109
#                                    6       H            -0.0029     -0.0042      0.0128
#                                    7       N            -0.0122      0.0262     -0.0059
#                                    8       N            -0.0521     -0.0214      0.0262
#
#
#                                    Vibrational Mode      15
#                                    ----------------------------------------------------
#                                    Harmonic frequency:                2047.71  cm**-1
#                                    Reduced mass:                      11.5535  amu
#                                    Force constant:                    28.5430  mdyne/A
#                                    IR intensity:                     169.6570  km/mol
#                                    Normal mode:
#                                                               X           Y           Z
#                                    1       C             0.0271     -0.1136     -0.0019
#                                    2       C             0.0059      0.1241      0.0079
#                                    3       N            -0.0092     -0.1535     -0.0111
#                                    4       H            -0.0984     -0.3255      0.0640
#                                    5       H            -0.0474     -0.1848     -0.0140
#                                    6       H            -0.0982      0.1351     -0.0066
#                                    7       N             0.2775     -0.4588      0.0049
#                                    8       N            -0.2791      0.6304     -0.0020
#
#
#                                    Vibrational Mode      16
#                                    ----------------------------------------------------
#                                    Harmonic frequency:                3391.66  cm**-1
#                                    Reduced mass:                       1.0861  amu
#                                    Force constant:                     7.3609  mdyne/A
#                                    IR intensity:                      66.9546  km/mol
#                                    Normal mode:
#                                                               X           Y           Z
#                                    1       C            -0.0045     -0.0544     -0.0025
#                                    2       C             0.0327     -0.0552      0.0011
#                                    3       N            -0.0001     -0.0001     -0.0002
#                                    4       H            -0.0065      0.0032      0.0016
#                                    5       H             0.0578      0.6619      0.0298
#                                    6       H            -0.3895      0.6314     -0.0133
#                                    7       N             0.0004     -0.0000      0.0001
#                                    8       N            -0.0001      0.0008     -0.0000

# %% [markdown]
# ##### Animate the normal mode of choice (indexing starts with 1)

# %%
vib_drv.animate(vib_results, mode=1)
# Out:
# <div id="3dmolviewer_17575207120984967"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17575207120984967" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17575207120984967 = null;
# var warn = document.getElementById("3dmolwarning_17575207120984967");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17575207120984967 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17575207120984967"),{backgroundColor:"white"});
# viewer_17575207120984967.zoomTo();
# 	viewer_17575207120984967.addModel("8\n\nC 1.267384028538 0.858861037274 0.111578248080 0.352060 0.015799 0.039661\nC 1.514871770868 -0.354653532687 0.079330040429 0.338119 0.105301 0.048737\nN -0.878745542430 0.895731928573 -0.219123178544 -0.313033 0.018967 -0.034222\nH -1.690001642583 1.431578662084 0.102595977912 -0.522547 -0.253854 -0.116235\nH 1.377961209568 1.927169226772 0.160713109770 -0.242864 0.063377 -0.011417\nH 2.093028695206 -1.262042519530 0.099900426819 -0.257247 -0.257294 -0.030465\nN -0.381673301953 -1.312215794361 -0.182596621457 -0.279836 -0.116753 -0.035450\nN -1.037548344687 -0.348440777236 -0.199319887647 0.074648 0.026167 0.005252","xyz",{"vibrate": {"frames": 15, "amplitude": 0.5}});
# 	viewer_17575207120984967.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17575207120984967.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17575207120984967.animate({"loop": "backAndForth"});
# 	viewer_17575207120984967.rotate(-90,"x");
# 	viewer_17575207120984967.zoomTo();
# viewer_17575207120984967.render();
# });
# </script>

# %% [markdown]
# #### IRC
# After obtaining the TS, perform an intrinsic reaction coordinate (IRC) calculation to find the product and reactant.

# %% [markdown]
# ##### Setting up the SCF driver

# %%
molecule = vlx.Molecule.read_xyz_string(scf_opt_ts["final_geometry"])
basis = vlx.MolecularBasis.read(molecule,"def2-svp")

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.conv_thresh = 1.0e-6
scf_drv.xcfun = "b3lyp"
scf_drv.grid_level = 4
scf_irc_results = scf_drv.compute(molecule,basis)
# Out:
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Kohn-Sham
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#                    Exchange-Correlation Functional : B3LYP
#                    Molecular Grid Level            : 4
#
# * Info * Nuclear repulsion energy: 148.8029764468 a.u.
#
# * Info * Using the B3LYP functional.
#
#          P. J. Stephens, F. J. Devlin, C. F. Chabalowski, and M. J. Frisch.,  J. Phys. Chem. 98, 11623 (1994)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * Molecular grid with 121661 points generated in 0.10 sec.
#
# * Info * Overlap matrix computed in 0.00 sec.
#
# * Info * Kinetic energy matrix computed in 0.00 sec.
#
# * Info * Nuclear potential matrix computed in 0.00 sec.
#
# * Info * Orthogonalization matrix computed in 0.00 sec.
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -240.271814063223 a.u. Time: 0.20 sec.
#
# * Info * Overlap matrix computed in 0.00 sec.
#
# * Info * Kinetic energy matrix computed in 0.00 sec.
#
# * Info * Nuclear potential matrix computed in 0.00 sec.
#
# * Info * Orthogonalization matrix computed in 0.00 sec.
#
#
#                Iter. |    Kohn-Sham Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1      -241.876407247161    0.0000000000      0.48595865      0.03023715      0.00000000
#                   2      -241.839062399275    0.0373448479      0.72182418      0.05002553      0.36545124
#                   3      -241.896891652573   -0.0578292533      0.24997435      0.01733694      0.26234402
#                   4      -241.903260660054   -0.0063690075      0.07692042      0.00382481      0.07745868
#                   5      -241.903836185340   -0.0005755253      0.02242984      0.00098641      0.02564385
#                   6      -241.903894817438   -0.0000586321      0.00290787      0.00015478      0.00816259
#                   7      -241.903894949330   -0.0000001319      0.00276489      0.00015588      0.00184553
#                   8      -241.903895999052   -0.0000010497      0.00043047      0.00002327      0.00092490
#                   9      -241.903896019133   -0.0000000201      0.00017079      0.00000760      0.00018157
#                  10      -241.903896023476   -0.0000000043      0.00002669      0.00000174      0.00006788
#                  11      -241.903896023610   -0.0000000001      0.00000453      0.00000023      0.00001779
#                  12      -241.903896023614   -0.0000000000      0.00000097      0.00000006      0.00000269
#
#                *** SCF converged in 12 iterations. Time: 1.70 sec.
#
#                Spin-Restricted Kohn-Sham:
#                --------------------------
#                Total Energy                       :     -241.9038960236 a.u.
#                Electronic Energy                  :     -390.7068724704 a.u.
#                Nuclear Repulsion Energy           :      148.8029764468 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000009657 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                                  Spin Restricted Orbitals
#                                                  ------------------------
#
#                Molecular Orbital No.  14:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.42699 a.u.
#                (   7 N   1s  :    -0.16) (   7 N   2s  :    -0.32) (   7 N   3s  :    -0.48)
#                (   7 N   1p+1:     0.18) (   7 N   1p-1:    -0.38) (   8 N   1p+1:    -0.22)
#                (   8 N   1p-1:     0.20)
#
#                Molecular Orbital No.  15:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.32457 a.u.
#                (   1 C   1p+1:     0.18) (   3 N   2s  :    -0.17) (   3 N   3s  :    -0.32)
#                (   3 N   1p+1:     0.36) (   3 N   2p+1:    -0.21) (   4 H   1s  :     0.20)
#                (   7 N   1p+1:    -0.22) (   7 N   1p-1:    -0.24) (   7 N   2p-1:     0.17)
#                (   8 N   1p+1:    -0.21)
#
#                Molecular Orbital No.  16:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.29161 a.u.
#                (   1 C   1p0 :     0.43) (   1 C   2p0 :     0.25) (   2 C   1p0 :     0.41)
#                (   2 C   2p0 :     0.24)
#
#                Molecular Orbital No.  17:
#                --------------------------
#                Occupation: 2.000 Energy:   -0.27019 a.u.
#                (   1 C   1p+1:    -0.29) (   1 C   2p+1:    -0.17) (   2 C   1p+1:    -0.25)
#                (   3 N   3s  :    -0.15) (   3 N   1p0 :    -0.33) (   3 N   2p0 :     0.26)
#                (   7 N   1p0 :     0.28) (   7 N   2p0 :    -0.20) (   8 N   1p+1:     0.17)
#
#                Molecular Orbital No.  18:
#                --------------------------
#                Occupation: 2.000 Energy:   -0
#                                    X   :        -0.242227 a.u.        -0.615680 Debye
#                                    Y   :         0.712090 a.u.         1.809953 Debye
#                                    Z   :         0.257673 a.u.         0.654939 Debye
#                                  Total :         0.795073 a.u.         2.020875 Debye

# %% [markdown]
# ##### Setting up the gradient driver

# %%
scf_grad_drv = vlx.ScfGradientDriver(scf_drv)
scf_grad_drv.compute(molecule,basis)
# Out:
#
#                                                    SCF Gradient Driver
#                                                   =====================
#
#                           Gradient Type                   : Analytical
#
#                                               Molecular Geometry (Angstroms)
#                                              ================================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            C           1.267384028538        0.858861037274        0.111578248080
#                            C           1.514871770868       -0.354653532687        0.079330040429
#                            N          -0.878745542430        0.895731928573       -0.219123178544
#                            H          -1.690001642583        1.431578662084        0.102595977912
#                            H           1.377961209568        1.927169226772        0.160713109770
#                            H           2.093028695206       -1.262042519530        0.099900426819
#                            N          -0.381673301953       -1.312215794361       -0.182596621457
#                            N          -1.037548344687       -0.348440777236       -0.199319887647
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            C           0.000051193033       -0.000088250478       -0.000011591518
#                            C          -0.000023006080        0.000091227526        0.000003631685
#                            N           0.000039544083       -0.000075798418        0.000001574304
#                            H          -0.000103898054        0.000068805859        0.000031565419
#                            H          -0.000031295980       -0.000003097391       -0.000000926937
#                            H          -0.000025989414        0.000004775624       -0.000002578470
#                            N          -0.000104774256       -0.000013729943        0.000005682970
#                            N           0.000163027461        0.000003899385       -0.000016168332
#
#                                    *** Time spent in gradient calculation: 1.51 sec ***

# %% [markdown]
# ##### Setting up the optimization driver for the IRC

# %%
scf_opt_drv = vlx.OptimizationDriver(scf_grad_drv)
scf_opt_drv.irc = True  
scf_opt_drv.hessian = 'first'  # IRC usually uses Hessian from TS
scf_opt_drv.ostream.mute()
scf_opt_irc = scf_opt_drv.compute(molecule,basis,scf_irc_results)

# %% [markdown]
# ##### Visualization of the optimized reactant and product geometries

# %%
scf_opt_irc["opt_energies"] # use to investigate energies of reactant and product
# Out:
# [np.float64(-242.04407422005022),
#  np.float64(-242.044073930066),
#  np.float64(-242.04407261220445),
#  np.float64(-242.04407050517236),
#  np.float64(-242.0440681675856),
#  np.float64(-242.04406623076426),
#  np.float64(-242.0440584379007),
#  np.float64(-242.04404118386623),
#  np.float64(-242.04379683698338),
#  np.float64(-242.0431403036591),
#  np.float64(-242.04184646285162),
#  np.float64(-242.0398373239964),
#  np.float64(-242.03715179403363),
#  np.float64(-242.0338613664231),
#  np.float64(-242.030043361477),
#  np.float64(-242.02577329527054),
#  np.float64(-242.02112312962143),
#  np.float64(-242.01616063989732),
#  np.float64(-242.01094906597908),
#  np.float64(-242.00554695273797),
#  np.float64(-242.00000811220406),
#  np.float64(-241.9943816581402),
#  np.float64(-241.9887124839437),
#  np.float64(-241.98304083828646),
#  np.float64(-241.97740365271437),
#  np.float64(-241.9718347595887),
#  np.float64(-241.96636517138612),
#  np.float64(-241.9345849629563),
#  np.float64(-241.93463224579222),
#  np.float64(-241.93467455813686),
#  np.float64(-241.93471201437725),
#  np.float64(-241.93474531462135),
#  np.float64(-241.93477540250666),
#  np.float64(-241.93480291537642),
#  np.float64(-241.93482801697436),
#  np.float64(-241.93485170943228),
#  np.float64(-241.9348746453),
#  np.float64(-241.934897443238),
#  np.float64(-241.9349207936972),
#  np.float64(-241.93494507654555),
#  np.float64(-241.93497019996124),
#  np.float64(-241.9349955114014),
#  np.float64(-241.9350212174332),
#  np.float64(-241.93504893964814),
#  np.float64(-241.93507875840365),
#  np.float64(-241.93511042539473),
#  np.float64(-241.93513096427554),
#  np.float64(-241.93515536504188),
#  np.float64(-241.9351843997592),
#  np.float64(-241.93521776057457),
#  np.float64(-241.93525070284093),
#  np.float64(-241.93527847283772),
#  np.float64(-241.935288419106),
#  np.float64(-241.93529185914662),
#  np.float64(-241.93529313603477),
#  np.float64(-241.93529507334497),
#  np.float64(-241.93529785179555),
#  np.float64(-241.93530182116857),
#  np.float64(-241.93530744107446),
#  np.float64(-241.9353154243331),
#  np.float64(-241.9353267770798),
#  np.float64(-241.93533060632072),
#  np.float64(-241.93533538077196),
#  np.float64(-241.9353444730177),
#  np.float64(-241.935344626289)]

# %%
reactant = vlx.Molecule.from_xyz_string(scf_opt_irc['opt_geometries'][-1])
product = vlx.Molecule.from_xyz_string(scf_opt_irc['opt_geometries'][0])
reactant.show()
product.show()
reactant.write_xyz_file('irc_reactant.xyz')
product.write_xyz_file('irc_product.xyz')
# Out:
# <div id="3dmolviewer_17636274643095717"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17636274643095717" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17636274643095717 = null;
# var warn = document.getElementById("3dmolwarning_17636274643095717");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17636274643095717 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17636274643095717"),{backgroundColor:"white"});
# viewer_17636274643095717.zoomTo();
# 	viewer_17636274643095717.addModel("8\n\nC              1.963287093229         0.982015369936         0.105291420045\nC              2.238209609543        -0.179894524942         0.298668703371\nN             -1.460434232070         0.827302650220        -0.276330906607\nH             -1.289729771523         1.269366848856         0.632351376542\nH              1.724628316844         2.012670168881        -0.081679675109\nH              2.479477268781        -1.213802825425         0.464700004679\nN             -0.952760834579        -1.479566292806        -0.334427849179\nN             -1.173953082568        -0.371856780738        -0.229588244044\n");
# 	viewer_17636274643095717.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17636274643095717.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17636274643095717.zoomTo();
# viewer_17636274643095717.render();
# });
# </script>
# <div id="3dmolviewer_17636274643106685"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17636274643106685" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17636274643106685 = null;
# var warn = document.getElementById("3dmolwarning_17636274643106685");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17636274643106685 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17636274643106685"),{backgroundColor:"white"});
# viewer_17636274643106685.zoomTo();
# 	viewer_17636274643106685.addModel("8\n\nC              0.826955235958         0.848966526519         0.038272203262\nC              1.112457914669        -0.501332235693         0.020169000301\nN             -0.521424918369         0.884234454777        -0.113647682844\nH             -1.137937983304         1.689220921431        -0.150804913986\nH              1.438935972171         1.740874787458         0.141089344763\nH              2.071001889785        -1.007726001647         0.109612361045\nN             -0.054175694557        -1.188325851655        -0.137304147174\nN             -1.039807206625        -0.349904457946        -0.217513990767\n");
# 	viewer_17636274643106685.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17636274643106685.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17636274643106685.zoomTo();
# viewer_17636274643106685.render();
# });
# </script>

# %%
scf_opt_drv.show_convergence(scf_opt_irc)
# Out:
# <div id="3dmolviewer_17575441508076408"  style="position: relative; width: 640px; height: 360px;">
#         <p id="3dmolwarning_17575441508076408" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.2/build/3Dmol-min.js');
# }
#
# var viewer_17575441508076408 = null;
# var warn = document.getElementById("3dmolwarning_17575441508076408");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17575441508076408 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17575441508076408"),{backgroundColor:"white"});
# viewer_17575441508076408.zoomTo();
# 	viewer_17575441508076408.addModel("8\n\nC              1.963287093229         0.982015369936         0.105291420045\nC              2.238209609543        -0.179894524942         0.298668703371\nN             -1.460434232070         0.827302650220        -0.276330906607\nH             -1.289729771523         1.269366848856         0.632351376542\nH              1.724628316844         2.012670168881        -0.081679675109\nH              2.479477268781        -1.213802825425         0.464700004679\nN             -0.952760834579        -1.479566292806        -0.334427849179\nN             -1.173953082568        -0.371856780738        -0.229588244044\n");
# 	viewer_17575441508076408.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17575441508076408.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17575441508076408.zoomTo();
# viewer_17575441508076408.render();
# });
# </script>
# interactive(children=(IntSlider(value=155, description='step', max=155), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# ### Calculation of Thermodynamic and Kinetic Parameters

# %% [markdown]
# With calculated values of reactant, product, and transition state, we now compute thermodynamic and kinetic quantities for a chemical reaction:
#
# - Activation free energy ($\Delta G^\ddagger$)
# - Reaction rate via Transition State Theory
# - Reaction free energy ($\Delta G^\circ$)

# %% [markdown]
# - **Activation free energy** <br>
# By definition the activation free energy is $\Delta G^{\ddagger} = G^{\ddagger} - G_{react}$.
# From the outputs of the TS and reactant we can get the activation energy $\Delta G^{\ddagger}$ that we can relate with TST to estimate the rate of the reaction.

# %%
delta_g = scf_opt_ts['opt_energies'][-1]-scf_opt_irc['opt_energies'][-1]
print(f"Activation energy is {627.5095 * delta_g:.2f} kcal/mol")
# Out:
# Activation energy is 19.73 kcal/mol

# %% [markdown]
# - **Reaction rate**<br>
# Applying Transition State Theory we can estimate the rate with the Eyring equation: <br />
# $ k = \frac{k_B T}{h}\exp(\frac{-\Delta G^{\ddagger}}{RT}) $

# %%
import numpy as np

def rate(delta_g):
    k_B = 1.3806e-23  # J/K
    h = 6.6261e-34    # J s
    R = 1.987e-3      # kcal/mol K
    T = 300           # K

    delta_g_kcal = delta_g * 627.5095
    
    # Eyring equation
    k = (k_B * T / h) * np.exp(-delta_g_kcal / (R * T))
    return k

# %%
print(f"The reaction rate is {rate(delta_g):.3e} s-1")
# Out:
# The reaction rate is 2.620e-02 s-1

# %% [markdown]
# - **Reaction free energy** <br>
# Finally, we can determine the reaction free energy $\Delta G^{0}$ as the free energy difference between reactant and product:

# %%
reaction_energy = scf_opt_irc["opt_energies"][0] - scf_opt_irc["opt_energies"][-1] # a.u
reaction_energy_kcal = reaction_energy *627.5095 # kcal/mol

# %%
print(f"Reaction free energy is {reaction_energy_kcal:.2f} kcal/mol")
# Out:
# Reaction free energy is -68.23 kcal/mol

# %% [markdown]
# With all that information we have proffiled the reaction energetics.
