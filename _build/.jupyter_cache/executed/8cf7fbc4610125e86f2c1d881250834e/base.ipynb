# %%
import veloxchem as vlx

# %%
molecule = vlx.Molecule.read_smiles("OC=CC=O")
molecule.show(atom_indices=True)
# Out:
# <div id="3dmolviewer_17639904507689018"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17639904507689018" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17639904507689018 = null;
# var warn = document.getElementById("3dmolwarning_17639904507689018");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17639904507689018 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17639904507689018"),{backgroundColor:"white"});
# viewer_17639904507689018.zoomTo();
# 	viewer_17639904507689018.addModel("9\n\nO             -1.840967000000         1.574582000000         1.070339000000\nC             -0.544627000000         1.087880000000         1.193415000000\nC             -0.333519000000        -0.225160000000         1.279347000000\nC              1.012494000000        -0.802632000000         1.410990000000\nO              2.039289000000        -0.073244000000         1.448933000000\nH             -2.009576000000         2.570847000000         1.004506000000\nH              0.282021000000         1.787977000000         1.217934000000\nH             -1.179944000000        -0.900182000000         1.252008000000\nH              1.122884000000        -1.876743000000         1.476620000000\n");
# 	viewer_17639904507689018.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17639904507689018.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17639904507689018.addLabel("1",{"position": {"x": -1.8409669999999998, "y": 1.574582, "z": 1.070339}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.addLabel("2",{"position": {"x": -0.544627, "y": 1.08788, "z": 1.193415}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.addLabel("3",{"position": {"x": -0.333519, "y": -0.22516, "z": 1.279347}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.addLabel("4",{"position": {"x": 1.012494, "y": -0.8026319999999999, "z": 1.4109899999999997}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.addLabel("5",{"position": {"x": 2.039289, "y": -0.073244, "z": 1.448933}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.addLabel("6",{"position": {"x": -2.009576, "y": 2.570847, "z": 1.004506}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.addLabel("7",{"position": {"x": 0.282021, "y": 1.787977, "z": 1.2179339999999999}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.addLabel("8",{"position": {"x": -1.179944, "y": -0.900182, "z": 1.2520079999999998}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.addLabel("9",{"position": {"x": 1.122884, "y": -1.876743, "z": 1.47662}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17639904507689018.zoomTo();
# viewer_17639904507689018.render();
# });
# </script>

# %%
scf_drv = vlx.XtbDriver()
scf_drv.ostream.mute()

opt_drv = vlx.OptimizationDriver(scf_drv)
opt_drv.ostream.mute()

# %%
conformer_energies = []
conformer_structures = []

cis, trans = 0.0, 180.0

hocc, occc, ccco = (6, 1, 2, 3), (1, 2, 3, 4), (2, 3, 4, 5)

for i in (cis, trans):
    for j in (cis, trans):
        for k in (cis, trans):

            molecule = vlx.Molecule.read_smiles("OC=CC=O")

            molecule.set_dihedral_in_degrees(hocc, i)
            molecule.set_dihedral_in_degrees(occc, j)
            molecule.set_dihedral_in_degrees(ccco, k)

            opt_results = opt_drv.compute(molecule)
            conformer_energies.append(opt_results["opt_energies"][-1])
            conformer_structures.append(opt_results["final_geometry"])

# %%
import numpy as np

conformer_energies = np.array(conformer_energies)

idx_lowest_conformer = np.argmin(conformer_energies)

# %%
lowest_conformer = vlx.Molecule.read_xyz_string(
    conformer_structures[idx_lowest_conformer]
)
lowest_conformer.show()
# Out:
# <div id="3dmolviewer_1763990458263285"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_1763990458263285" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1763990458263285 = null;
# var warn = document.getElementById("3dmolwarning_1763990458263285");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1763990458263285 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1763990458263285"),{backgroundColor:"white"});
# viewer_1763990458263285.zoomTo();
# 	viewer_1763990458263285.addModel("9\n\nO             -0.095256067994         0.910364068984        -0.686243522620\nC              0.413808870319        -0.259810136740        -0.985802019849\nC              0.685179599268        -1.231771385685        -0.078589884050\nC              0.411725394880        -1.004264362057         1.311343361043\nO             -0.063263162241         0.032416993838         1.759881522902\nH             -0.233233469404         0.931136673313         0.303192824536\nH              0.606670111699        -0.394425098490        -2.045277252353\nH              1.103412065702        -2.172361840573        -0.388402011121\nH              0.656556831515        -1.836052388318         1.991576455546\n");
# 	viewer_1763990458263285.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1763990458263285.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1763990458263285.zoomTo();
# viewer_1763990458263285.render();
# });
# </script>

# %%
print("Conformer  Energy (kcal/mol)\n" + 27 * "-")
for i, conformer_energy in enumerate(
    (conformer_energies - np.min(conformer_energies)) * vlx.hartree_in_kcalpermol()
):
    print(f"{i+1:>2d} {conformer_energy:14.2f}")
# Out:
# Conformer  Energy (kcal/mol)
# ---------------------------
#  1           0.00
#  2           7.43
#  3           5.81
#  4           5.78
#  5          12.97
#  6          10.24
#  7           8.44
#  8           9.34
