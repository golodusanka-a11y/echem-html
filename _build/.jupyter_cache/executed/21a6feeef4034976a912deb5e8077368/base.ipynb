# %%
import veloxchem as vlx

ammonia_str = "N"
molecule = vlx.Molecule.read_smiles(ammonia_str)
molecule.show()
# Out:
# <div id="3dmolviewer_1763990123112594"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_1763990123112594" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1763990123112594 = null;
# var warn = document.getElementById("3dmolwarning_1763990123112594");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1763990123112594 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1763990123112594"),{backgroundColor:"white"});
# viewer_1763990123112594.zoomTo();
# 	viewer_1763990123112594.addModel("4\n\nN             -2.260803000000        -0.467240000000         1.503184000000\nH             -1.812953000000         0.270409000000         0.914866000000\nH             -2.913853000000        -0.992661000000         0.880071000000\nH             -1.504495000000        -1.133952000000         1.775773000000\n");
# 	viewer_1763990123112594.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1763990123112594.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1763990123112594.zoomTo();
# viewer_1763990123112594.render();
# });
# </script>

# %%
pg = vlx.SymmetryAnalyzer()

pg_results = pg.identify_pointgroup(molecule, tolerance="very tight")
pg.print_symmetry_results(pg_results)
# Out:
# Principal moments of inertia: Doubly degenerate
# Point group: C3v
# Expected symmetry elements: E, 2C3, 3sigma_v

# %%
pg.print_tolerance_keywords()
# Out:
# ['very loose', 'loose', 'tight', 'very tight']

# %%
water = """3 

O       12.0448432299       -3.9158679908        0.9692506110
H       11.2081241979       -4.3238710922        1.0042469492
H       12.4653859253       -4.3498515284        0.2216705986
"""

molecule = vlx.Molecule.read_xyz_string(water)

pg_results_verytight = pg.identify_pointgroup(molecule, tolerance="very tight")
print("Tolerance: very tight")
pg.print_symmetry_results(pg_results_verytight, symmetry_info=False)

pg_results_loose = pg.identify_pointgroup(molecule, tolerance="loose")
print("\nTolerance: loose")
pg.print_symmetry_results(pg_results_loose, symmetry_info=False)
# Out:
# Tolerance: very tight
# Point group: Cs
# Tolerance: loose
# Point group: C2v

# %%
symmetrized_molecule = pg.symmetrize_pointgroup(pg_results_loose)

symmetrized_coords = symmetrized_molecule.get_coordinates_in_angstrom()
print("Symmetrized coordinates:")
print(symmetrized_coords, "\n")

pg_symmetrized_results = pg.identify_pointgroup(symmetrized_molecule, tolerance="very tight")
pg.print_symmetry_results(pg_symmetrized_results, symmetry_info=False)
# Out:
# Symmetrized coordinates:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [-7.40190619e-01  5.65603978e-01 -1.25234164e-30]
#  [ 7.40190619e-01  5.65603978e-01 -1.25234164e-30]]
# Point group: C2v

# %%
smiles_str = "O"
molecule = vlx.Molecule.read_smiles(smiles_str)
molecule.show()
# Out:
# <div id="3dmolviewer_17639901240440562"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17639901240440562" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17639901240440562 = null;
# var warn = document.getElementById("3dmolwarning_17639901240440562");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17639901240440562 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17639901240440562"),{backgroundColor:"white"});
# viewer_17639901240440562.zoomTo();
# 	viewer_17639901240440562.addModel("3\n\nO              2.523945000000         1.756689000000         2.129013000000\nH              1.968003000000         2.536245000000         1.876377000000\nH              2.121665000000         1.427829000000         2.972000000000\n");
# 	viewer_17639901240440562.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17639901240440562.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17639901240440562.zoomTo();
# viewer_17639901240440562.render();
# });
# </script>

# %%
smiles_str = "C=CC=C"
molecule = vlx.Molecule.read_smiles(smiles_str)
molecule.show()
# Out:
# <div id="3dmolviewer_1763990124053729"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_1763990124053729" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1763990124053729 = null;
# var warn = document.getElementById("3dmolwarning_1763990124053729");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1763990124053729 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1763990124053729"),{backgroundColor:"white"});
# viewer_1763990124053729.zoomTo();
# 	viewer_1763990124053729.addModel("10\n\nC              1.284305000000         1.098963000000        -2.563575000000\nC              0.765670000000         0.555489000000        -1.466340000000\nC             -0.028625000000        -0.681259000000        -1.532233000000\nC             -0.547261000000        -1.224731000000        -0.434998000000\nH              1.137129000000         0.647214000000        -3.536960000000\nH              1.865611000000         2.009163000000        -2.493360000000\nH              0.935660000000         1.038170000000        -0.510869000000\nH             -0.198617000000        -1.163939000000        -2.487705000000\nH             -0.400085000000        -0.772982000000         0.538387000000\nH             -1.128565000000        -2.134933000000        -0.505212000000\n");
# 	viewer_1763990124053729.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1763990124053729.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1763990124053729.zoomTo();
# viewer_1763990124053729.render();
# });
# </script>

# %%
smiles_str = "C=C"
molecule = vlx.Molecule.read_smiles(smiles_str)
molecule.show()
# Out:
# <div id="3dmolviewer_1763990124061406"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_1763990124061406" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1763990124061406 = null;
# var warn = document.getElementById("3dmolwarning_1763990124061406");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1763990124061406 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1763990124061406"),{backgroundColor:"white"});
# viewer_1763990124061406.zoomTo();
# 	viewer_1763990124061406.addModel("6\n\nC             -0.096462000000        -0.248522000000         0.111555000000\nC             -1.309363000000        -0.331520000000         0.653331000000\nH              0.500110000000         0.648567000000         0.241764000000\nH              0.303139000000        -1.077443000000        -0.463623000000\nH             -1.905935000000        -1.228609000000         0.523121000000\nH             -1.708963000000         0.497401000000         1.228509000000\n");
# 	viewer_1763990124061406.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1763990124061406.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1763990124061406.zoomTo();
# viewer_1763990124061406.render();
# });
# </script>

# %%
smiles_str = "C"
molecule = vlx.Molecule.read_smiles(smiles_str)
molecule.show()
# Out:
# <div id="3dmolviewer_17639901240683231"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17639901240683231" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_17639901240683231 = null;
# var warn = document.getElementById("3dmolwarning_17639901240683231");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17639901240683231 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17639901240683231"),{backgroundColor:"white"});
# viewer_17639901240683231.zoomTo();
# 	viewer_17639901240683231.addModel("5\n\nC              0.236317000000        -0.729955000000        -1.662468000000\nH              0.537735000000        -1.606480000000        -1.052860000000\nH              0.707230000000        -0.797020000000        -2.664722000000\nH              0.567846000000         0.201760000000        -1.159709000000\nH             -0.867542000000        -0.718080000000        -1.772581000000\n");
# 	viewer_17639901240683231.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17639901240683231.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17639901240683231.zoomTo();
# viewer_17639901240683231.render();
# });
# </script>

# %%
basis = vlx.MolecularBasis.read(molecule, "6-311G*", ostream=None)

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.ostream.mute()

scf_results = scf_drv.compute(molecule, basis)

mo_energy = scf_results["E_alpha"]

print("Number of orbitals:", len(mo_energy))
print("\nMO energies (au):\n", mo_energy)
# Out:
# Number of orbitals: 30
#
# MO energies (au):
#  [-11.21735938  -0.93497078  -0.54106631  -0.54106623  -0.54106617
#    0.15932294   0.23597851   0.23597852   0.23597855   0.42631604
#    0.42631604   0.42631611   0.73162231   0.8088004    0.80880046
#    0.80880053   0.98927954   1.52218854   1.52218855   1.78626674
#    1.78626675   1.78626676   2.56348216   2.74055773   2.74055788
#    2.74055831   3.4601744    3.46017464   3.4601749   24.5357593 ]

# %%
triethylamine_str = """22

C        1.4406481432        0.0964240130        0.3244873324
H        3.2906450569        0.8452272094       -0.5124741371
N       -0.0014686419       -0.0219647619       -0.0423208350
H        1.7900781091       -0.9279183758        0.5865664594
H        1.8324905179        1.6211670774       -1.1719487368
H        1.5737680055        0.7169324638        1.2372357058
H        2.2799678814       -0.0144983028       -1.6847624599
C        2.2541279270        0.6634233123       -0.8219830073
C       -0.6475206978        1.3101098975       -0.2332627068
H       -2.4973892956        2.1439562492       -0.9858487429
H        0.0586500605        1.9257351766       -0.8352531348
H       -2.6400781276        0.4651573835       -0.4162187295
H       -0.7757885617        1.8375684814        0.7368898718
H       -1.8671050093        0.8149782404       -1.9714528173
C       -1.9809853937        1.1772135262       -0.9416709671
C       -0.7583008561       -0.8859778302        0.9110685781
H       -0.7899056566       -2.9391400606        1.5946073856
H       -1.8350392006       -0.7932273386        0.6425616259
H        0.7857470680       -2.4128325981        0.9593727577
H       -0.6614928673       -0.5143242997        1.9543149991
H       -0.5451457820       -2.7778882813       -0.1515159458
C       -0.3058710735       -2.3298995341        0.8214627280
"""
molecule = vlx.Molecule.read_xyz_string(triethylamine_str)
molecule.show()
# Out:
# <div id="3dmolviewer_1763990124436906"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_1763990124436906" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.0/build/3Dmol-min.js');
# }
#
# var viewer_1763990124436906 = null;
# var warn = document.getElementById("3dmolwarning_1763990124436906");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1763990124436906 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1763990124436906"),{backgroundColor:"white"});
# viewer_1763990124436906.zoomTo();
# 	viewer_1763990124436906.addModel("22\n\nC              1.440648143200         0.096424013000         0.324487332400\nH              3.290645056900         0.845227209400        -0.512474137100\nN             -0.001468641900        -0.021964761900        -0.042320835000\nH              1.790078109100        -0.927918375800         0.586566459400\nH              1.832490517900         1.621167077400        -1.171948736800\nH              1.573768005500         0.716932463800         1.237235705800\nH              2.279967881400        -0.014498302800        -1.684762459900\nC              2.254127927000         0.663423312300        -0.821983007300\nC             -0.647520697800         1.310109897500        -0.233262706800\nH             -2.497389295600         2.143956249200        -0.985848742900\nH              0.058650060500         1.925735176600        -0.835253134800\nH             -2.640078127600         0.465157383500        -0.416218729500\nH             -0.775788561700         1.837568481400         0.736889871800\nH             -1.867105009300         0.814978240400        -1.971452817300\nC             -1.980985393700         1.177213526200        -0.941670967100\nC             -0.758300856100        -0.885977830200         0.911068578100\nH             -0.789905656600        -2.939140060600         1.594607385600\nH             -1.835039200600        -0.793227338600         0.642561625900\nH              0.785747068000        -2.412832598100         0.959372757700\nH             -0.661492867300        -0.514324299700         1.954314999100\nH             -0.545145782000        -2.777888281300        -0.151515945800\nC             -0.305871073500        -2.329899534100         0.821462728000\n");
# 	viewer_1763990124436906.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_1763990124436906.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_1763990124436906.zoomTo();
# viewer_1763990124436906.render();
# });
# </script>

# %%
basis = vlx.MolecularBasis.read(molecule, "6-31G", ostream=None)

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.ostream.mute()

scf_results = scf_drv.compute(molecule, basis)

mo_energy = scf_results["E_alpha"]

print("Number of orbitals:", len(mo_energy))
print("\nMO energies (au):\n", mo_energy)
# Out:
# Number of orbitals: 93
#
# MO energies (au):
#  [-15.54578849 -11.25090355 -11.25090355 -11.25087358 -11.21246683
#  -11.21246653 -11.21246653  -1.21131333  -1.02510881  -1.02510881
#   -0.95516387  -0.84457492  -0.84457492  -0.76156233  -0.63980813
#   -0.63980813  -0.61995786  -0.58982172  -0.58982172  -0.54558603
#   -0.52774456  -0.51291914  -0.51291914  -0.50152399  -0.4839755
#   -0.4839755   -0.4473856   -0.4473856   -0.33930113   0.23557939
#    0.24581183   0.24581183   0.27338951   0.29363159   0.29363159
#    0.30611874   0.31534336   0.31534336   0.33506903   0.33506903
#    0.34579136   0.36436004   0.38908878   0.38908878   0.40390215
#    0.42832684   0.42832684   0.45960101   0.45960101   0.4814887
#    0.73810901   0.73810901   0.76078307   0.77961338   0.77961338
#    0.80202299   0.82977804   0.82977804   0.83162343   0.92269428
#    0.95025505   0.95025505   0.95533729   0.98746581   0.98746581
#    1.07603196   1.07603196   1.11600443   1.12617684   1.19648957
#    1.20455251   1.20455251   1.22181746   1.22181746   1.22709025
#    1.24353097   1.2508069    1.2508069    1.26259608   1.26259608
#    1.29418576   1.32269348   1.32269348   1.35323599   1.4345424
#    1.44579073   1.44579073   1.64418987   1.64418987   1.77919534
#    1.92026477   1.92026477   2.06059262]
